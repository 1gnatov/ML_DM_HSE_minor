# %% [markdown]
# # Майнор "Интеллектуальный анализ данных", курс "Введение в программирование".

# %% [markdown]
# <img src="../img/faculty_logo.jpg" height="240" width="240">

# %% [markdown]
# # Семинар 5. Словари. Множества. Стиль программирования на Python (Стандарт PEP-8). Документирование кода. (Стандарт PEP-257).

# %% [markdown]
# # Часть 3. Стиль программирования на Python (Стандарт PEP-8).
# Про стандарт PEP-8 на <a href="http://pythonworld.ru/osnovy/pep-8-rukovodstvo-po-napisaniyu-koda-na-python.html">Pythonworld</a>

# %% [markdown]
# - Используйте 4 пробела на каждый уровень отступа
# - Ограничьте длину строки максимум 79 символами
# - Используйте пустые строки в функциях, чтобы указать логические разделы.
# - Используйте кодировку UTF-8. Начиная с версии python 3.0 в стандартной библиотеке действует следующее соглашение: все идентификаторы обязаны содержать только ASCII символы, и означать английские слова везде, где это возможно
# - Каждый импорт, как правило, должен быть на отдельной строке. Импорты должны быть сгруппированы в следующем порядке: импорты из стандартной библиотеки, из сторонних библиотек и из модулей текущего проекта
# - Всегда окружайте бинарные операторы одним пробелом с каждой стороны: присваивания (=, +=, -= и другие), сравнения (==, <, >, !=, <>, <=, >=, in, not in, is, is not), логические (and, or, not).
# - Комментарии, противоречащие коду, хуже, чем отсутствие комментариев. Всегда исправляйте комментарии, если меняете код!. Комментарии должны являться законченными предложениями
# - Модули должны иметь короткие имена, состоящие из маленьких букв. Имена функций должны состоять из маленьких букв, а слова разделяться символами подчеркивания — это необходимо, чтобы увеличить читабельность. Имена классов должны обычно следовать соглашению CapWords (CamelCase). Константы обычно объявляются на уровне модуля и записываются только заглавными буквами, а слова разделяются символами подчеркивания
# - ...

# %% [markdown]
# # Часть 4. Документирование кода. (Стандарт PEP-257).

# %% [markdown]
# Про стандарт PEP-257 на <a href="http://pythonworld.ru/osnovy/dokumentirovanie-koda-v-python-pep-257.html">Pythonworld</a>

# %% [markdown]
# **Строки документации** - строковые литералы, которые являются первым оператором в модуле, функции, классе или определении метода. Такая строка документации становится специальным атрибутом \__doc\__ этого объекта.
#
# Все модули должны, как правило, иметь строки документации, и все функции и классы, экспортируемые модулем также должны иметь строки документации. Публичные методы (в том числе \__init\__) также должны иметь строки документации. Пакет модулей может быть документирован в \__init\__.py.
#
# Строку документации принято выделять тройными кавычками.
#
# Многострочные строки документации состоят из однострочной строки документации с последующей пустой строкой, а затем более подробным описанием. Первая строка может быть использована автоматическими средствами индексации, поэтому важно, чтобы она находилась на одной строке и была отделена от остальной документации пустой строкой.
#
# **Пример** документированной функции:

# %%
def sum_factorials(n):
    """Calculate sum of factorials.
    
    Function that calculates sum of factorials: 1! + 2! + ... + n!
    :param n - integer
    
    """
    run_sum, total_sum = 1, 0
    for i in xrange(n):
        run_sum *= (i + 1)
        total_sum += run_sum
    return total_sum

# %% [markdown]
# Строка документации - это то, что возвращает метод help для данного объекта, например, функции.

# %%
help(sum_factorials)
# Out:
# Help on function sum_factorials in module __main__:
#
# sum_factorials(n)
#     Function that calculates sum of factorials: 1! + 2! + ... + n!
#     :param n - integer
