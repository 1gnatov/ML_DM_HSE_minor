# %%
text = "hello mum you are a nice mum"

# %%
words = text.split()

# %%
words
# Out:
# ['hello', 'mum', 'you', 'are', 'a', 'nice', 'mum']

# %%
word_freq = {}

# %%
for word in words:
    if word in word_freq:
        word_freq[word] += 1
    else: # it's a new word
        word_freq[word] = 1

# %%
word_freq
# Out:
# {'a': 1, 'are': 1, 'hello': 1, 'mum': 2, 'nice': 1, 'you': 1}

# %%
sms_file = open('../../data/sms_data.txt')

# %%
sms_file.readline()
# Out:
# 'ham\tGo until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...\n'

# %%
s = ' ham\tGo until jurong point, crazy.. '+ \
'Available only in bugis n great world la e ' + \
'buffet... Cine there got amore wat...\n'

# %%
word_freq = {}

for line in sms_file:
    words = line.strip().split()
    for word in words:
        if word in word_freq:
            word_freq[word] += 1
        else:
            word_freq[word] = 1

# %%
sorted(word_freq.items(), key=lambda (k,v): -v)
# Out:
# [('ham', 4827),
#  ('to', 2145),
#  ('you', 1626),
#  ('I', 1469),
#  ('a', 1337),
#  ('the', 1207),
#  ('and', 858),
#  ('in', 799),
#  ('is', 788),
#  ('i', 748),
#  ('spam', 747),
#  ('u', 698),
#  ('for', 650),
#  ('my', 630),
#  ('of', 592),
#  ('your', 561),
#  ('me', 561),
#  ('on', 488),
#  ('have', 477),
#  ('2', 457),
#  ('that', 422),
#  ('it', 397),
#  ('are', 397),
#  ('call', 376),
#  ('or', 373),
#  ('be', 363),
#  ('at', 360),
#  ('with', 351),
#  ('not', 344),
#  ('will', 333),
#  ('get', 326),
#  ('can', 304),
#  ('U', 300),
#  ('ur', 297),
#  ('so', 295),
#  ("I'm", 286),
#  ('but', 284),
#  ('&lt;#&gt;', 276),
#  ('You', 263),
#  ('from', 256),
#  ('4', 255),
#  ('up', 243),
#  ('do', 242),
#  ('.', 241),
#  ('if', 239),
#  ('just', 238),
#  ('go', 235),
#  ('when', 234),
#  ('like', 224),
#  ('know', 224),
#  ('this', 223),
#  ('we', 222),
#  ('all', 218),
#  ('out', 207),
#  ('got', 203),
#  ('was', 200),
#  ('come', 199),
#  ('now', 190),
#  ('?', 187),
# ...

# %%
# !echo '1 2 3 2 1' > 'input.txt'

# %%
input_str = open('input.txt').readline().strip()
outfile = open('output.txt', 'w')

# %%
input_str.split()
# Out:
# ['1', '2', '3', '2', '1']

# %%
outfile.write(str(len(set(input_str.split()))))
outfile.close()

# %%
# !cat output.txt
# Out:
# 3
